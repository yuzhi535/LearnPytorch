# %%
import torch
import torchvision
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import torch.nn as nn
import torchvision.transforms as transforms
from torchvision import datasets

# %%
transform = transforms.Compose(
    [transforms.ToTensor(), transforms.CenterCrop(128), transforms.Normalize(mean=.5, std=.5)])

dataset = datasets.ImageFolder(root='./data/cats_dogs/', transform=transform)

example = iter(dataset)

sample, lables = example.__next__()
print(sample.shape)
# Out:
# torch.Size([3, 128, 128])

# %%
example.__next__()
sample, lables = example.__next__()
plt.imshow(np.transpose(sample, (1, 2, 0)))
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
data_loader = torch.utils.data.DataLoader(dataset=dataset, batch_size=4, shuffle=True, num_workers=0)

# %%
train_features, train_labels = next(iter(data_loader))

for i in range(4):
    image = train_features[i]
    plt.subplot(2, 2, i+1)
    image = np.transpose(image.numpy(), (1, 2, 0))
    plt.imshow(image)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
conv = nn.Conv2d(3, 3, kernel_size=3)
nn.init.xavier_uniform_(conv.weight)
out = conv(train_features)
out = conv(out)

for i in range(4):
    image = out[i]
    # image  = transforms.ToPILImage()
    plt.subplot(2, 2, i+1)
    image = np.transpose(image.detach().numpy(), (1, 2, 0))
    plt.imshow(image)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
out = conv(out)
out = conv(out)

for i in range(4):
    image = out[i]
    plt.subplot(2, 2, i+1)
    image = np.transpose(image.detach().numpy(), (1, 2, 0))
    plt.imshow(image)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
